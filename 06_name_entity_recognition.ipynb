# %%
sentence = """
The Charminar (lit. 'four minarets') is a monument located in Hyderabad, Telangana, India. Constructed in 1591, the landmark is a symbol of Hyderabad and officially incorporated in the emblem of Telangana.[3] The Charminar's long history includes the existence of a mosque on its top floor for more than 434 years. While both historically and religiously significant, it is also known for its popular and busy local markets surrounding the structure, and has become one of the most frequented tourist attractions in Hyderabad. Charminar is also a site of numerous festival celebrations, such as Eid-ul-adha and Eid al-Fitr,[4] as it is adjacent to the city's main mosque, the Makkah Masjid.
"""

# %%
import nltk
words=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(words)

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Rohith\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in .\venv\lib\site-packages (2.3.5)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install svgling
# Out:
# Collecting svgling
#   Downloading svgling-0.5.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting svgwrite (from svgling)
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading svgling-0.5.0-py3-none-any.whl (31 kB)
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ---------------------------------------- 0.0/67.1 kB ? eta -:--:--
#    ---------------------------------------- 67.1/67.1 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.5.0 svgwrite-1.4.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Rohith\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [('The', 'DT'), ('Charminar', 'NNP'), ('(', '('), ('lit', 'NN'), ('.', '.'), ("'four", 'CD'), ('minarets', 'NNS'), ("'", 'POS'), (')', ')'), ('is', 'VBZ'), ('a', 'DT'), ('monument', 'NN'), ('located', 'VBN'), ('in', 'IN'), Tree('GPE', [('Hyderabad', 'NNP')]), (',', ','), Tree('GPE', [('Telangana', 'NNP')]), (',', ','), Tree('GPE', [('India', 'NNP')]), ('.', '.'), ('Constructed', 'VBN'), ('in', 'IN'), ('1591', 'CD'), (',', ','), ('the', 'DT'), ('landmark', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('symbol', 'NN'), ('of', 'IN'), Tree('GPE', [('Hyderabad', 'NNP')]), ('and', 'CC'), ('officially', 'RB'), ('incorporated', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('emblem', 'NN'), ('of', 'IN'), Tree('GPE', [('Telangana', 'NNP')]), ('.', '.'), ('[', 'CC'), ('3', 'CD'), (']', 'IN'), ('The', 'DT'), Tree('ORGANIZATION', [('Charminar', 'NNP')]), ("'s", 'POS'), ('long', 'JJ'), ('history', 'NN'), ('includes', 'VBZ'), ('the', 'DT'), ('existence', 'NN'), ('of', 'IN'), ('a', 'DT'), ('mosque', 'NN'), ('on', 'IN'), ('its', 'PRP$'), ('top', 'JJ'), ('floor', 'NN'), ('for', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('434', 'CD'), ('years', 'NNS'), ('.', '.'), ('While', 'IN'), ('both', 'DT'), ('historically', 'RB'), ('and', 'CC'), ('religiously', 'RB'), ('significant', 'JJ'), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('also', 'RB'), ('known', 'VBN'), ('for', 'IN'), ('its', 'PRP$'), ('popular', 'JJ'), ('and', 'CC'), ('busy', 'JJ'), ('local', 'JJ'), ('markets', 'NNS'), ('surrounding', 'VBG'), ('the', 'DT'), ('structure', 'NN'), (',', ','), ('and', 'CC'), ('has', 'VBZ'), ('become', 'VBN'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('frequented', 'JJ'), ('tourist', 'NN'), ('attractions', 'NNS'), ('in', 'IN'), Tree('GPE', [('Hyderabad', 'NNP')]), ('.', '.'), Tree('PERSON', [('Charminar', 'NNP')]), ('is', 'VBZ'), ('also', 'RB'), ('a', 'DT'), ('site', 'NN'), ('of', 'IN'), ('numerous', 'JJ'), ('festival', 'JJ'), ('celebrations', 'NNS'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('Eid-ul-adha', 'NNP'), ('and', 'CC'), Tree('PERSON', [('Eid', 'NNP')]), ('al-Fitr', 'NN'), (',', ','), ('[', 'VBZ'), ('4', 'CD'), (']', 'NN'), ('as', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('adjacent', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('city', 'NN'), ("'s", 'POS'), ('main', 'JJ'), ('mosque', 'NN'), (',', ','), ('the', 'DT'), Tree('ORGANIZATION', [('Makkah', 'NNP'), ('Masjid', 'NNP')]), ('.', '.')])

# %%
nltk.ne_chunk(tag_elements).draw()
