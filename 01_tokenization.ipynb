# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Rohith\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
corpus =""" Hello welcome to NLP.
This is an example of tokenization. This helps in text use cases like
sentiment analysis, text classification, etc.
"""

# %%
print(corpus)
# Out:
#  Hello welcome to NLP.
# This is an example of tokenization. This helps in text use cases like
# sentiment analysis, text classification, etc.

# %%
## Tokenization
## Sentence --> Paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello welcome to NLP.
# This is an example of tokenization.
# This helps in text use cases like
# sentiment analysis, text classification, etc.

# %%
## Tokenization
## Paragraph --> Words
## sentence --> words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'NLP',
#  '.',
#  'This',
#  'is',
#  'an',
#  'example',
#  'of',
#  'tokenization',
#  '.',
#  'This',
#  'helps',
#  'in',
#  'text',
#  'use',
#  'cases',
#  'like',
#  'sentiment',
#  'analysis',
#  ',',
#  'text',
#  'classification',
#  ',',
#  'etc',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', 'to', 'NLP', '.']
# ['This', 'is', 'an', 'example', 'of', 'tokenization', '.']
# ['This', 'helps', 'in', 'text', 'use', 'cases', 'like', 'sentiment', 'analysis', ',', 'text', 'classification', ',', 'etc', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'NLP',
#  '.',
#  'This',
#  'is',
#  'an',
#  'example',
#  'of',
#  'tokenization',
#  '.',
#  'This',
#  'helps',
#  'in',
#  'text',
#  'use',
#  'cases',
#  'like',
#  'sentiment',
#  'analysis',
#  ',',
#  'text',
#  'classification',
#  ',',
#  'etc',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'NLP.',
#  'This',
#  'is',
#  'an',
#  'example',
#  'of',
#  'tokenization.',
#  'This',
#  'helps',
#  'in',
#  'text',
#  'use',
#  'cases',
#  'like',
#  'sentiment',
#  'analysis',
#  ',',
#  'text',
#  'classification',
#  ',',
#  'etc',
#  '.']
